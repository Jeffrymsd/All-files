# %%
##pip install bs4

# %%
##pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=boat+airdopes&sid=0pm%2Cfcn%2C821%2Ca7x%2C2si&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=boat+airdopes%7CTrue+Wireless&requestId=9a6b9c34-5666-45db-bdc9-d76dbe881339"

# %%
flipkart=requests.get(url)

# %%
flipkart
# Out:
# <Response [200]>

# %%
response=BeautifulSoup(flipkart.text)

# %%
response
# Out:
# <!DOCTYPE html>
# ...

# %%
name=response.select("._1AtVbE+ .col-12-12 .s1Q9rs:nth-child(2) , ._2GoDe3+ .col-12-12 ._4HTuuX~ .s1Q9rs")

# %%
name
# Out:
# [<a class="s1Q9rs" href="/boat-airdopes-131-upto-60-hours-asap-charge-bluetooth-headset/p/itmf76c6f983fbca?pid=ACCFSDGXX3S6DVBG&amp;lid=LSTACCFSDGXX3S6DVBGISMVSQ&amp;marketplace=FLIPKART&amp;q=boat+airdopes&amp;store=0pm%2Ffcn%2F821%2Fa7x%2F2si&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&amp;fm=organic&amp;iid=en_Mfs9C5MKo07G2RFbajcQZ8K1lTFkCQ4VWdznaIYXStF%2FPUE4DQOEyTSPZTKghmyGPiUadXRJkwkjunLy89IrVQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=cmxfe1ywcw0000001670818531936&amp;qH=7c82039a894b5615" rel="noopener noreferrer" target="_blank" title="boAt Airdopes 131 with upto 60 Hours and ASAP Charge Bluetooth Headset">boAt Airdopes 131 with upto 60 Hours and ASAP Charge Bl...</a>,
# ...

# %%
price=response.select(".col-12-12:nth-child(9) ._30jeq3 , .col-12-12:nth-child(8) ._30jeq3 , .col-12-12:nth-child(7) div+ div ._30jeq3 , div:nth-child(4) ._30jeq3 , ._13oc-S div:nth-child(2) ._8VNy32:nth-child(5) ._30jeq3 , ._2GoDe3+ .col-12-12 div~ div+ div ._30jeq3 , ._2GoDe3+ .col-12-12 ._13oc-S div:nth-child(1) ._4ddWXP ._30jeq3")

# %%
price
# Out:
# [<div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹1,399</div>,
#  <div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹1,499</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹1,499</div>,
#  <div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹899</div>,
#  <div class="_30jeq3">₹1,699</div>,
#  <div class="_30jeq3">₹1,299</div>,
#  <div class="_30jeq3">₹1,599</div>,
#  <div class="_30jeq3">₹1,699</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹799</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹1,599</div>,
#  <div class="_30jeq3">₹1,399</div>,
#  <div class="_30jeq3">₹1,699</div>,
#  <div class="_30jeq3">₹1,999</div>,
#  <div class="_30jeq3">₹1,499</div>,
#  <div class="_30jeq3">₹899</div>,
#  <div class="_30jeq3">₹949</div>,
#  <div class="_30jeq3">₹799</div>,
#  <div class="_30jeq3">₹899</div>,
# ...

# %%
offer=response.select(".col-12-12:nth-child(6) ._13oc-S div:nth-child(1) ._4ddWXP span , ._13oc-S div+ div ._8VNy32:nth-child(5) span")

# %%
offer
# Out:
# [<span>43% off</span>,
#  <span>56% off</span>,
#  <span>49% off</span>,
#  <span>56% off</span>,
#  <span>56% off</span>,
#  <span>82% off</span>,
#  <span>51% off</span>,
#  <span>56% off</span>,
#  <span>56% off</span>,
#  <span>Ad</span>,
#  <span class="_1lRcqv" id="productRating_LSTACCGDQMAAJAZBZ43666LLF_ACCGDQMAAJAZBZ43_"><div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div></span>,
#  <span class="_2_R_DZ">(56,818)</span>,
#  <span>49% off</span>,
#  <span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span>,
#  <span>Add to Compare</span>,
#  <span>53% off</span>,
#  <span>46% off</span>,
#  <span>51% off</span>,
#  <span>59% off</span>,
#  <span>59% off</span>,
#  <span>59% off</span>,
#  <span>46% off</span>,
#  <span>68% off</span>,
#  <span>59% off</span>,
#  <span>49% off</span>,
#  <span>79% off</span>,
#  <span>80% off</span>,
#  <span>49% off</span>,
#  <span>84% off</span>,
# ...

# %%
import pandas

# %%
import pandas as pd

# %%
airdopes=pd.DataFrame(name,columns=["airdopes name"])
airdopes["airdopes prize"]=price
airdopes["airdopes offer"]=offer

# %%
airdopes
# Out:
#                                         airdopes name airdopes prize  \
# 0   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 1   boAt Airdopes 161 with ASAP Charge, 10mm Drive...       [₹1,399]
# 2   boAt Airdopes 161 with ASAP Charge, 10mm Drive...       [₹1,299]
# 3   boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,499]
# 4   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,999]
# 5   boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,499]
# 6   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 7   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,999]
# 8   boAt Airdopes 191G with 6mm Dual Drivers, Quad...         [₹899]
# 9   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,699]
# 10  boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 11  boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,599]
# 12  boAt Airdopes 115 with ENx & Beast Mode, upto ...       [₹1,699]
# ...

# %%
airdopes.to_csv('C:\\Users\\a\\jeffry\\df.csv')

# %%
mm=pd.read_csv('C:\\Users\\a\\jeffry\\df.csv')

# %%
airdopes
# Out:
#                                         airdopes name airdopes prize  \
# 0   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 1   boAt Airdopes 161 with ASAP Charge, 10mm Drive...       [₹1,399]
# 2   boAt Airdopes 161 with ASAP Charge, 10mm Drive...       [₹1,299]
# 3   boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,499]
# 4   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,999]
# 5   boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,499]
# 6   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 7   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,999]
# 8   boAt Airdopes 191G with 6mm Dual Drivers, Quad...         [₹899]
# 9   boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,699]
# 10  boAt Airdopes 131 with upto 60 Hours and ASAP ...       [₹1,299]
# 11  boAt Airdopes 131 PRO with 11mm Drivers,45Hrs ...       [₹1,599]
# 12  boAt Airdopes 115 with ENx & Beast Mode, upto ...       [₹1,699]
# ...
