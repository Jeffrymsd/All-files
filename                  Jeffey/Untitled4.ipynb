# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv('C:/Users/a/Downloads/Admission_Predict_Ver1.1 (1).csv')

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
GA.shape
# Out:
# (500, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
Newdataset=GA.drop(['University Rating','Serial No.','GRE Score','TOEFL Score','SOP','LOR','Research'],axis=1)

# %%
Newdataset
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 495  9.02              0.87
# 496  9.87              0.96
# 497  9.56              0.93
# 498  8.43              0.73
# 499  9.04              0.84
#
# [500 rows x 2 columns]

# %%
x=Newdataset.iloc[:,0].values.reshape(-1,1)
y=Newdataset.iloc[:,-1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('TOEFL Score')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[0.58421497],
#        [0.83706099],
#        [0.79070589],
#        [0.82863279],
#        [0.62846302],
#        [0.66428287],
#        [0.57157266],
#        [0.70642388],
#        [0.58000087],
#        [0.75910013],
#        [0.63267712],
#        [0.72117323],
#        [0.65164057],
#        [0.81177639],
#        [0.82652574],
#        [0.57789382],
#        [0.78649179],
#        [0.62635597],
#        [0.78859884],
#        [0.55893036],
#        [0.52732461],
#        [0.67271107],
#        [0.53364576],
#        [0.8918443 ],
#        [0.83284689],
#        [0.71485208],
#        [0.68535338],
#        [0.48729066],
#        [0.60107137],
#        [0.61582072],
#        [0.75699308],
#        [0.44936375],
#        [0.70010273],
#        [0.80756229],
#        [0.52732461],
#        [0.53575281],
#        [0.84970329],
#        [0.86445264],
#        [0.63689122],
#        [0.67903223],
#        [0.65796172],
#        [0.87498789],
#        [0.86023854],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['TOEFL Score'])

# %%
COMP
# Out:
#      TOEFL Score
# 0           7.92
# 1           9.12
# 2           8.90
# 3           9.08
# 4           8.13
# ..           ...
# 245         8.76
# 246         7.67
# 247         8.27
# 248         8.78
# 249         9.60
#
# [250 rows x 1 columns]

# %%
COMP['AVLDATA']=Y_test

# %%
COMP
# Out:
#      GRE Score  AVLDATA
# 0         7.92     0.64
# 1         9.12     0.85
# 2         8.90     0.80
# 3         9.08     0.91
# 4         8.13     0.68
# ..         ...      ...
# 245       8.76     0.77
# 246       7.67     0.59
# 247       8.27     0.69
# 248       8.78     0.79
# 249       9.60     0.90
#
# [250 rows x 2 columns]

# %%
COMP['PRDDATA']=y_predict

# %%
COMP
# Out:
#      GRE Score  AVLDATA   PRDDATA
# 0         7.92     0.64  0.584215
# 1         9.12     0.85  0.837061
# 2         8.90     0.80  0.790706
# 3         9.08     0.91  0.828633
# 4         8.13     0.68  0.628463
# ..         ...      ...       ...
# 245       8.76     0.77  0.761207
# 246       7.67     0.59  0.531539
# 247       8.27     0.69  0.657962
# 248       8.78     0.79  0.765421
# 249       9.60     0.90  0.938199
#
# [250 rows x 3 columns]
